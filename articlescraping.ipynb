# %%
from newspaper import Article

# %%
content="https://www.timesnownews.com/education/article/iit-roorkee-student-who-teaches-poor-kids-for-free-awarded-gold-medal-from-president-ram-nath-kovind/499743"

# %%
tnarticle=Article(content)

# %%
title=tnarticle.title

# %%
tnarticle.download()

# %%
tnarticle.parse()

# %%
print(tnarticle.title)
# Out:
# IIT Roorkee student who teaches poor kids for free receives gold medal from President Ram Nath Kovind

# %%
print(tnarticle.text)
# Out:
# President Ram Nath Kovind (File image) | Photo Credit: PTI
#
# Roorkee: IIT Roorkee student Anant Vashistha, who taught underprivileged students from a nearby village for free, received a gold medal from President Ram Nath Kovind on Friday for making an excellent contribution in the field of youth leadership.
#
# The 22-year-old student, who completed his B.Tech in Production and Industrial Engineering this year, won the prestigious Dr Jai Krishna Gold Medal for excellent contribution in the field of youth leadership amongst students admitted through JEE.
#
# President Kovind felicitated him with the medal during IIT Roorkee's 19th annual convocation here where eight other students were also awarded.
#
# Vashistha, who now works at Master Card in Gurgaon, said he started taking classes free of cost for the poor and underprivileged students of Kaliyar village near his college in 2015 after his enrolment.
#
# ...

# %%
print(tnarticle.images)
# Out:
# {'https://cloudfront.timesnownews.com/site/static/web_t5/web_new/images/android.svg', 'https://imgk.timesnownews.com/story/ram_nath_kovind_pti.jpg?tr=w-560,h-292,fo-top', 'https://www.facebook.com/tr?id=781440862041802&ev=PageView&noscript=1', 'https://cloudfront.timesnownews.com/site/static/web_t5/web_new/images/footer-insta.svg', 'https://cloudfront.timesnownews.com/site/static/web_t5/web_new/images/logo.png', 'https://imgk.timesnownews.com/story/GettyImages-870341860.jpg?tr=w-200,h-150', 'https://cloudfront.timesnownews.com/site/static/web_t5/images/icons/et_logo.png', 'https://cloudfront.timesnownews.com/site/static/web_t3/images/icon-mobile-mask.png', 'https://img.timesnownews.com/story/Kempegowda_International_Airport.jpg?tr=w-100,h-75', 'https://cloudfront.timesnownews.com/site/static/web_t5/web_new/images/footer-twitter.svg', 'https://imgk.timesnownews.com/story/JEE_Main_2018_Dates.jpg?tr=w-200,h-150', 'https://cloudfront.timesnownews.com/site/static/web_t5/web_new/images/app
# ...

# %%
print(tnarticle.keywords)
# Out:
# ['village', 'children', 'ram', 'students', 'president', 'free', 'youth', 'medal', 'teaches', 'kovind', 'roorkee', 'poor', 'student', 'receives', 'nath', 'vashistha', 'classes', 'teaching']

# %%
print(tnarticle.top_image)
# Out:
# https://imgk.timesnownews.com/story/ram_nath_kovind_pti.jpg?tr=w-560,h-292,fo-top

# %%
print(tnarticle.authors)
# Out:
# []

# %%
print(tnarticle.movies)
# Out:
# []

# %%
import newspaper

# %%
tnarticle=newspaper.build("https://www.timesnownews.com/education/article/iit-roorkee-student-who-teaches-poor-kids-for-free-awarded-gold-medal-from-president-ram-nath-kovind/499743")

# %%
for article in tnarticle.articles:
    print(article.url)
# Out:
# https://www.timesnownews.com/entertainment/news
# https://www.timesnownews.com/entertainment/news/people
# https://www.timesnownews.com/entertainment/news/international-news
# https://www.timesnownews.com/entertainment/news/bollywood-news
# https://www.timesnownews.com/videos/et-now/news
# https://www.timesnownews.com/livetv/timesnow/video
# https://www.timesnownews.com/education/article/madras-hc-directs-tn-health-dept-central-govt-to-file-detailed-report-in-neet-impersonation-matter/499807
# https://www.timesnownews.com/education/article/iit-roorkee-student-who-teaches-poor-kids-for-free-awarded-gold-medal-from-president-ram-nath-kovind/499743
# https://www.timesnownews.com/education/article/ssc-si-asi-exam-2019-important-notice-released-regarding-vacancies-on-ssc-nic-in/499728
# https://www.timesnownews.com/education/article/learn-english-are-you-a-foodie-here-are-10-words-and-their-synonyms-to-describe-food/499701
# ...

# %%
for category in tnarticle.category_urls():
    print(category)
# Out:
# https://www.timesnownews.com/education
# https://www.timesnownews.com/education/article/iit-roorkee-student-who-teaches-poor-kids-for-free-awarded-gold-medal-from-president-ram-nath-kovind/499743
# https://www.timesnownews.com
# https://www.timesnownews.com/mirror-now
# https://www.timesnownews.com/health
# https://www.timesnownews.com/sports
# https://www.timesnownews.com/india
# https://hindi.timesnownews.com
# https://www.timesnownews.com/videos
# https://www.timesnownews.com/the-newshour
# https://www.timesnownews.com/lifestyle
# https://www.timesnownews.com/spiritual
# https://www.timesnownews.com/trending-news
# https://www.timesnownews.com/latest-news
# https://www.timesnownews.com/international
# https://www.timesnownews.com/auto
# https://www.timesnownews.com/india-upfront
# https://www.timesnownews.com/photos
# https://www.timesnownews.com/entertainment
# https://www.timesnownews.com/astrology
# https://www.timesnownews.com/the-buzz
